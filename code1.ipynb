# %% [markdown]
# <a href="https://colab.research.google.com/github/dryahyavi/dryahyavi/blob/main/code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x = np.arange (-80 , 81, 0.5)
y = x**2 + 2*x -10

# %%
x.shape , y.shape
# Out:
# ((322,), (322,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y ,train_size =0.2)
x_train.shape , y_train.shape
# Out:
# ((64,), (64,))

# %% [markdown]
# difine model

# %%
model = keras.Sequential()
model.add (keras.layers.Dense (units= 64 , activation='relu' , input_shape= [1]))
model.add (keras.layers.Dense (units= 64 , activation='relu' ))
model.add (keras.layers.Dense (units= 32 , activation='relu' ))
model.add (keras.layers.Dense (units= 32 , activation='relu' ))


model.add (keras.layers.Dense (units= 1))


model.add (keras.layers.Dense(units=1 ))

# %%
optimizer = keras.optimizers.Adam ()
loss = tf.losses.MeanSquaredError
metric =keras.metrics.RootMeanSquaredError()

model.compile (optimizer =optimizer ,loss= loss , metrics= [metric] )

# %%
model.summary ()
# Out:
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_66 (Dense)                │ (None, 64)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 1)              │            33 │
# ...

# %%
from sklearn.utils.validation import validate_data
call_back= keras.callbacks.EarlyStopping ( monitor='val_loss' , patience= 500,
                                          restore_best_weights=True)


his = model.fit(x_train , y_train , epochs= 600 ,batch_size= 32, callbacks=[call_back],
                validation_data = (x_test , y_test))
# Out:
# Epoch 1/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step - loss: 10048385.0000 - root_mean_squared_error: 3167.9058 - val_loss: 8081812.0000 - val_root_mean_squared_error: 2842.8528
# Epoch 2/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 9113656.0000 - root_mean_squared_error: 3017.2334 - val_loss: 8080834.0000 - val_root_mean_squared_error: 2842.6807
# Epoch 3/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8962853.0000 - root_mean_squared_error: 2990.6614 - val_loss: 8079795.5000 - val_root_mean_squared_error: 2842.4980
# Epoch 4/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 10088238.0000 - root_mean_squared_error: 3173.8469 - val_loss: 8078741.5000 - val_root_mean_squared_error: 2842.3127
# Epoch 5/600
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8866569.0000 - root_mean_squared_error: 2973.3179 - val_loss: 8077662.0000 - val_root_mean_squared_error: 2842.1228
# Epoch 6/600
# ...

# %%
import matplotlib.pyplot as plt

plt.plot (his.history['val_loss'], color='red')
plt.plot (his.history['loss'], color='blue')
plt.show ()

# %%
y_pred = model.predict (x_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
x_test
# Out:
# array([ 52. , -29.5,  76. ,  73. ,  31. ,  54. ,  33.5, -49.5,  49.5,
#         72.5, -37.5, -62. ,   4. ,  61. , -13. , -16. , -27. ,  22.5,
#        -46.5,  71.5, -33.5, -13.5, -34.5,  63.5, -20.5, -56. ,  27.5,
#          5.5, -77.5,  10.5,  24. , -43.5,  -7. , -55.5, -25.5, -71. ,
#        -18. ,  31.5, -62.5,  -9. ,  40. ,  28.5,  -1.5,  -9.5, -28.5,
#        -79. , -72. ,  42.5, -22. ,   3. ,  46.5,  62. , -63. , -38.5,
#         74.5,  53. , -50. ,   1. , -43. , -44. ,  15.5, -41.5,  21.5,
#          8.5, -80. ,  -1. ,   6.5, -42.5, -25. ,  16. ,  25. ,   6. ,
#         61.5,  53.5,  19.5,  47. ,  35. , -46. , -52.5,  44.5, -47. ,
#         20. ,  32.5, -79.5,  59. , -57.5,  60. ,  80.5,  18. , -17.5,
#         42. , -22.5,  -6. ,  45.5,  13.5,  36.5, -26.5,  37.5, -40.5,
#        -58. , -51. ,  -0.5, -17. , -45.5,  38. ,  70. , -30.5, -35.5,
#        -58.5, -31. , -67. , -59.5, -52. ,  72. , -27.5, -55. ,  49. ,
# ...

# %%
plt.scatter (x_test , y_test , color= 'blue')
plt.scatter (x_test , y_pred, color ='red')

# %%
y_pred
# Out:
# array([[ 3.37984473e+03],
#        [ 1.66649475e+03],
#        [ 5.04808643e+03],
#        [ 4.83955615e+03],
#        [ 1.92013416e+03],
#        [ 3.51886499e+03],
#        [ 2.09390918e+03],
#        [ 2.91861157e+03],
#        [ 3.20606982e+03],
#        [ 4.80480176e+03],
#        [ 2.16734131e+03],
#        [ 3.70118481e+03],
#        [ 5.60558052e+01],
#        [ 4.00543555e+03],
#        [ 6.33498291e+02],
#        [ 8.21315857e+02],
#        [ 1.50998022e+03],
#        [ 1.32929858e+03],
#        [ 2.73079419e+03],
#        [ 4.73529150e+03],
#        [ 1.91691821e+03],
#        [ 6.64801208e+02],
#        [ 1.97952417e+03],
#        [ 4.17921094e+03],
#        [ 1.10304211e+03],
#        [ 3.32554980e+03],
#        [ 1.67684875e+03],
#        [ 1.55812393e+02],
#        [ 4.67157568e+03],
#        [ 4.95177917e+02],
#        [ 1.43356360e+03],
#        [ 2.54297656e+03],
#        [ 2.58866394e+02],
#        [ 3.29424683e+03],
#        [ 1.41607141e+03],
# ...
